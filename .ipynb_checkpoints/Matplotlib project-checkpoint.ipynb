# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
plt.plot([0,1,2,3])
plt.ylabel('label y')
# Out:
# Text(0, 0.5, 'label y')

# %%
plt.plot([1,3,4,9],[-1,8,1,2], 'b+')

# %%
t = np.arange(0,5,0.2)
plt.plot(t,t*2, 'r-')
plt.plot(t,t**2, 'r--')
plt.plot(t,t, 'bs')

# %%
plt.plot(t,t, 'r-',t,t**2, 'bs', t, t**3, 'g^')
# Out:
# [<matplotlib.lines.Line2D at 0x2975ab7e690>,
#  <matplotlib.lines.Line2D at 0x2975be36c10>,
#  <matplotlib.lines.Line2D at 0x2975be350d0>]

# %%
data = {
    'a': np.arange(500),
    'b': np.random.randint(0,50,500),
    'c': np.random.randn(500)
}

# %%
plt.scatter(data['a'], data['c'])
